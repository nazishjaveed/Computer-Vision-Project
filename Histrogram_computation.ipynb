# %% [markdown]
# # Plot the histrogram of foothball image

# %%
img = cv2.imread('foothball_img.webp')

# %%
import cv2
import matplotlib.pyplot as plt

# Assuming 'img' is your image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray_hist = cv2.calcHist([gray], [0], None, [256], [0, 256])

plt.figure()
plt.title('Grayscale Histogram')

plt.subplot(211)
plt.ylabel('No of Pixels')
plt.plot(gray_hist)
plt.xlim([0, 256])

plt.subplot(212)
plt.xlabel('Intensity of Pixels')

colors = ('b','g','r')

for i,col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0,256])
    plt.plot(hist, color=col)
    plt.xlim(0,256)

plt.show()
# Out:
# C:\Users\nazish\AppData\Local\Temp\ipykernel_16080\3897465422.py:12: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(211)
